# %% [markdown]
# # EDA of FMP data used for DCF

# %%
# building a functino to extract data from financialmodelingprep.com
import requests
import pandas as pd
import numpy as np
import json
import datetime

def get_statement(company_ticker, statement_name, api_key, frequency='annual', df = False):
    """
    Get a financial statement to use for fundamental calculations

    inputs:
    company_ticker (str) -- e.g. 'AAPL' for Apple inc.
    statement_name (str) -- one of: 'income-statement','balance-sheet-statement','cash-flow-statement','enterprise-value'
    period (str) -- 'annual' or 'quarter'
    forecast_period (int) -- Number of years you wish to forecast
    api_key (str) -- api key to access financialmodelingprep account

    returns:
    Pandas DataFrame object
    """
    if statement_name in ['income-statement','balance-sheet-statement','cash-flow-statement', 'enterprise-values', 'ratios']:

        statement = requests.get(f'https://financialmodelingprep.com/api/v3/{statement_name}/{company_ticker}?period={frequency}&apikey={api_key}').json()

        if df:
            statement = pd.DataFrame.from_dict(statement)
            statement = statement.iloc[:, 5:-2]  #these columns are not useful or repetitive


        else:
            pass

    return statement

# %%
# print statement eda to have a quick look at the data
def df_summary(df, name="DataFrame"):
    print(f"--- {name}.info() ---")
    print(df.info())
    print()

    print(f"--- {name}.describe() ---")
    print(df.describe(include='all'))
    print()

    print(f"--- {name}.head() ---")
    print(df.head())
    print()

# %%
#some columns only have zero as a value so we will drop them:
def drop_zero_columns(df):
    numeric_columns = df.select_dtypes(include=['number']).columns

    for column in numeric_columns:
        if df[column].sum() == 0:
            print(f'{column} only has zero values')
            df.drop(column, axis=1, inplace=True)

# %%
#data extraction from financial modelling prep

api_key= 'gUCO9waKiArsoKXiAzC2aiZtNsU0JmUb'
ticker= 'API'
company_ticker = ticker
base_url='https://financialmodelingprep.com/api/v3/'

# %%
# income statement
# some of the columns have only 0 values so they are dropped
income_statement = pd.DataFrame(get_statement(company_ticker, 'income-statement', api_key, frequency='annual', df=False))
if not income_statement.empty:
    income_statement = income_statement.iloc[:, 5:-2]

drop_zero_columns(income_statement)

df_summary(income_statement, name="Income Statement")
# Out:
# generalAndAdministrativeExpenses only has zero values
# sellingAndMarketingExpenses only has zero values
# otherExpenses only has zero values
# --- Income Statement.info() ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   acceptedDate                             5 non-null      object
#  1   calendarYear                             5 non-null      object
#  2   period                                   5 non-null      object
#  3   revenue                                  5 non-null      int64
#  4   costOfRevenue                            5 non-null      int64
#  5   grossProfit                              5 non-null      int64
#  6   grossProfitRatio                         5 non-null      float64
#  7   researchAndDevelopmentExpenses           5 non-null      int64
#  8   sellingGeneralAndAdministrativeExpenses  5 non-null      int64
#  9   operatingExpenses                        5 non-null      int64
#  10  costAndExpenses                          5 non-null      int64
#  11  interestIncome                           5 non-null      int64
#  12  interestExpense                          5 non-null      int64
#  13  depreciationAndAmortization              5 non-null      int64
#  14  ebitda                                   5 non-null      int64
#  15  ebitdaratio                              5 non-null      float64
#  16  operatingIncome                          5 non-null      int64
#  17  operatingIncomeRatio                     5 non-null      float64
#  18  totalOtherIncomeExpensesNet              5 non-null      int64
#  19  incomeBeforeTax                          5 non-null      int64
#  20  incomeBeforeTaxRatio                     5 non-null      float64
#  21  incomeTaxExpense                         5 non-null      int64
#  22  netIncome                                5 non-null      int64
#  23  netIncomeRatio                           5 non-null      float64
#  24  eps                                      5 non-null      float64
#  25  epsdiluted                               5 non-null      float64
#  26  weightedAverageShsOut                    5 non-null      int64
#  27  weightedAverageShsOutDil                 5 non-null      int64
# dtypes: float64(7), int64(18), object(3)
# memory usage: 1.2+ KB
# None
#
# --- Income Statement.describe() ---
#                acceptedDate calendarYear period       revenue  costOfRevenue  \
# count                     5            5      5  5.000000e+00   5.000000e+00
# unique                    5            5      1           NaN            NaN
# top     2024-11-01 06:01:36         2024     FY           NaN            NaN
# freq                      1            1      5           NaN            NaN
# mean                    NaN          NaN    NaN  3.617960e+11   2.061150e+11
# std                     NaN          NaN    NaN  5.002292e+10   2.103347e+10
# min                     NaN          NaN    NaN  2.745150e+11   1.695590e+11
# 25%                     NaN          NaN    NaN  3.658170e+11   2.103520e+11
# 50%                     NaN          NaN    NaN  3.832850e+11   2.129810e+11
# 75%                     NaN          NaN    NaN  3.910350e+11   2.141370e+11
# max                     NaN          NaN    NaN  3.943280e+11   2.235460e+11
#
#          grossProfit  grossProfitRatio  researchAndDevelopmentExpenses  \
# count   5.000000e+00          5.000000                    5.000000e+00
# unique           NaN               NaN                             NaN
# top              NaN               NaN                             NaN
# freq             NaN               NaN                             NaN
# mean    1.556810e+11          0.427319                    2.564040e+10
# std     3.006501e+10          0.029795                    5.310590e+09
# min     1.049560e+11          0.382332                    1.875200e+10
# 25%     1.528360e+11          0.417794                    2.191400e+10
# 50%     1.691480e+11          0.433096                    2.625100e+10
# 75%     1.707820e+11          0.441311                    2.991500e+10
# max     1.806830e+11          0.462063                    3.137000e+10
#
#         sellingGeneralAndAdministrativeExpenses  operatingExpenses  ...  \
# count                              5.000000e+00       5.000000e+00  ...
# unique                                      NaN                NaN  ...
# top                                         NaN                NaN  ...
# freq                                        NaN                NaN  ...
# mean                               2.360240e+10       4.924280e+10  ...
# std                                2.571975e+09       7.809846e+09  ...
# min                                1.991600e+10       3.866800e+10  ...
# 25%                                2.197300e+10       4.388700e+10  ...
# 50%                                2.493200e+10       5.134500e+10  ...
# 75%                                2.509400e+10       5.484700e+10  ...
# max                                2.609700e+10       5.746700e+10  ...
#
#         totalOtherIncomeExpensesNet  incomeBeforeTax  incomeBeforeTaxRatio  \
# count                  5.000000e+00     5.000000e+00              5.000000
# unique                          NaN              NaN                   NaN
# top                             NaN              NaN                   NaN
# freq                            NaN              NaN                   NaN
# mean                   8.620000e+07     1.065244e+11              0.291500
# std                    5.425318e+08     2.269405e+10              0.027370
# min                   -5.650000e+08     6.709100e+10              0.244398
# 25%                   -3.340000e+08     1.092070e+11              0.296740
# 50%                    2.580000e+08     1.137360e+11              0.298529
# 75%                    2.690000e+08     1.191030e+11              0.302040
# max                    8.030000e+08     1.234850e+11              0.315790
#
#         incomeTaxExpense     netIncome  netIncomeRatio       eps  epsdiluted  \
# count       5.000000e+00  5.000000e+00        5.000000  5.000000    5.000000
# unique               NaN           NaN             NaN       NaN         NaN
# top                  NaN           NaN             NaN       NaN         NaN
# freq                 NaN           NaN             NaN       NaN         NaN
# mean        1.799940e+10  8.852500e+10        0.242765  5.480000    5.442000
# std         7.459863e+09  1.755031e+10        0.020067  1.230163    1.227709
# min         9.680000e+09  5.741100e+10        0.209136  3.310000    3.280000
# 25%         1.452700e+10  9.373600e+10        0.239713  5.670000    5.610000
# 50%         1.674100e+10  9.468000e+10        0.253062  6.110000    6.080000
# 75%         1.930000e+10  9.699500e+10        0.253096  6.150000    6.110000
# max         2.974900e+10  9.980300e+10        0.258818  6.160000    6.130000
#
#         weightedAverageShsOut  weightedAverageShsOutDil
# count            5.000000e+00              5.000000e+00
# unique                    NaN                       NaN
# top                       NaN                       NaN
# freq                      NaN                       NaN
# mean             1.627147e+10              1.638792e+10
# std              7.896514e+08              8.400545e+08
# min              1.534378e+10              1.540810e+10
# 25%              1.574423e+10              1.581255e+10
# 50%              1.621596e+10              1.632582e+10
# 75%              1.670127e+10              1.686492e+10
# max              1.735212e+10              1.752821e+10
#
# [11 rows x 28 columns]
#
# --- Income Statement.head() ---
#           acceptedDate calendarYear period       revenue  costOfRevenue  \
# 0  2024-11-01 06:01:36         2024     FY  391035000000   210352000000
# 1  2023-11-02 18:08:27         2023     FY  383285000000   214137000000
# 2  2022-10-27 18:01:14         2022     FY  394328000000   223546000000
# 3  2021-10-28 18:04:28         2021     FY  365817000000   212981000000
# 4  2020-10-29 18:06:25         2020     FY  274515000000   169559000000
#
#     grossProfit  grossProfitRatio  researchAndDevelopmentExpenses  \
# 0  180683000000          0.462063                     31370000000
# 1  169148000000          0.441311                     29915000000
# 2  170782000000          0.433096                     26251000000
# 3  152836000000          0.417794                     21914000000
# 4  104956000000          0.382332                     18752000000
#
#    sellingGeneralAndAdministrativeExpenses  operatingExpenses  ...  \
# 0                              26097000000        57467000000  ...
# 1                              24932000000        54847000000  ...
# 2                              25094000000        51345000000  ...
# 3                              21973000000        43887000000  ...
# 4                              19916000000        38668000000  ...
#
#    totalOtherIncomeExpensesNet  incomeBeforeTax  incomeBeforeTaxRatio  \
# 0                    269000000     123485000000              0.315790
# 1                   -565000000     113736000000              0.296740
# 2                   -334000000     119103000000              0.302040
# 3                    258000000     109207000000              0.298529
# 4                    803000000      67091000000              0.244398
#
#    incomeTaxExpense    netIncome  netIncomeRatio   eps  epsdiluted  \
# 0       29749000000  93736000000        0.239713  6.11        6.08
# 1       16741000000  96995000000        0.253062  6.16        6.13
# 2       19300000000  99803000000        0.253096  6.15        6.11
# 3       14527000000  94680000000        0.258818  5.67        5.61
# 4        9680000000  57411000000        0.209136  3.31        3.28
#
#    weightedAverageShsOut  weightedAverageShsOutDil
# 0            15343783000               15408095000
# 1            15744231000               15812547000
# 2            16215963000               16325819000
# 3            16701272000               16864919000
# 4            17352119000               17528214000
#
# [5 rows x 28 columns]

# %%
# balance sheet yearly
balance_sheet = get_statement(company_ticker, 'balance-sheet-statement', api_key, frequency='annual', df=True)
drop_zero_columns(balance_sheet)
df_summary(balance_sheet, name="Balance Sheet")
# Out:
# goodwill only has zero values
# intangibleAssets only has zero values
# goodwillAndIntangibleAssets only has zero values
# otherAssets only has zero values
# deferredRevenueNonCurrent only has zero values
# deferredTaxLiabilitiesNonCurrent only has zero values
# otherLiabilities only has zero values
# preferredStock only has zero values
# othertotalStockholdersEquity only has zero values
# minorityInterest only has zero values
# --- Balance Sheet.info() ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 37 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   acceptedDate                             5 non-null      object
#  1   calendarYear                             5 non-null      object
#  2   period                                   5 non-null      object
#  3   cashAndCashEquivalents                   5 non-null      int64
#  4   shortTermInvestments                     5 non-null      int64
#  5   cashAndShortTermInvestments              5 non-null      int64
#  6   netReceivables                           5 non-null      int64
#  7   inventory                                5 non-null      int64
#  8   otherCurrentAssets                       5 non-null      int64
#  9   totalCurrentAssets                       5 non-null      int64
#  10  propertyPlantEquipmentNet                5 non-null      int64
#  11  longTermInvestments                      5 non-null      int64
#  12  taxAssets                                5 non-null      int64
#  13  otherNonCurrentAssets                    5 non-null      int64
#  14  totalNonCurrentAssets                    5 non-null      int64
#  15  totalAssets                              5 non-null      int64
#  16  accountPayables                          5 non-null      int64
#  17  shortTermDebt                            5 non-null      int64
#  18  taxPayables                              5 non-null      int64
#  19  deferredRevenue                          5 non-null      int64
#  20  otherCurrentLiabilities                  5 non-null      int64
#  21  totalCurrentLiabilities                  5 non-null      int64
#  22  longTermDebt                             5 non-null      int64
#  23  otherNonCurrentLiabilities               5 non-null      int64
#  24  totalNonCurrentLiabilities               5 non-null      int64
#  25  capitalLeaseObligations                  5 non-null      int64
#  26  totalLiabilities                         5 non-null      int64
#  27  commonStock                              5 non-null      int64
#  28  retainedEarnings                         5 non-null      int64
#  29  accumulatedOtherComprehensiveIncomeLoss  5 non-null      int64
#  30  totalStockholdersEquity                  5 non-null      int64
#  31  totalEquity                              5 non-null      int64
#  32  totalLiabilitiesAndStockholdersEquity    5 non-null      int64
#  33  totalLiabilitiesAndTotalEquity           5 non-null      int64
#  34  totalInvestments                         5 non-null      int64
#  35  totalDebt                                5 non-null      int64
#  36  netDebt                                  5 non-null      int64
# dtypes: int64(34), object(3)
# memory usage: 1.6+ KB
# None
#
# --- Balance Sheet.describe() ---
#                acceptedDate calendarYear period  cashAndCashEquivalents  \
# count                     5            5      5            5.000000e+00
# unique                    5            5      1                     NaN
# top     2024-11-01 06:01:36         2024     FY                     NaN
# freq                      1            1      5                     NaN
# mean                    NaN          NaN    NaN            3.130200e+10
# std                     NaN          NaN    NaN            5.490028e+09
# min                     NaN          NaN    NaN            2.364600e+10
# 25%                     NaN          NaN    NaN            2.994300e+10
# 50%                     NaN          NaN    NaN            2.996500e+10
# 75%                     NaN          NaN    NaN            3.494000e+10
# max                     NaN          NaN    NaN            3.801600e+10
#
#         shortTermInvestments  cashAndShortTermInvestments  netReceivables  \
# count           5.000000e+00                 5.000000e+00    5.000000e+00
# unique                   NaN                          NaN             NaN
# top                      NaN                          NaN             NaN
# freq                     NaN                          NaN             NaN
# mean            3.442040e+10                 6.572240e+10    5.542220e+10
# std             1.108647e+10                 1.554556e+10    1.136781e+10
# min             2.465800e+10                 4.830400e+10    3.744500e+10
# 25%             2.769900e+10                 6.155500e+10    5.150600e+10
# 50%             3.159000e+10                 6.263900e+10    6.093200e+10
# 75%             3.522800e+10                 6.517100e+10    6.098500e+10
# max             5.292700e+10                 9.094300e+10    6.624300e+10
#
#            inventory  otherCurrentAssets  totalCurrentAssets  ...  \
# count   5.000000e+00        5.000000e+00        5.000000e+00  ...
# unique           NaN                 NaN                 NaN  ...
# top              NaN                 NaN                 NaN  ...
# freq             NaN                 NaN                 NaN  ...
# mean    5.840800e+09        1.511600e+10        1.421014e+11  ...
# std     1.308021e+09        3.674502e+09        7.430787e+09  ...
# min     4.061000e+09        1.126400e+10        1.348360e+11  ...
# 25%     4.946000e+09        1.411100e+10        1.354050e+11  ...
# 50%     6.331000e+09        1.428700e+10        1.435660e+11  ...
# 75%     6.580000e+09        1.469500e+10        1.437130e+11  ...
# max     7.286000e+09        2.122300e+10        1.529870e+11  ...
#
#          commonStock  retainedEarnings  \
# count   5.000000e+00      5.000000e+00
# unique           NaN               NaN
# top              NaN               NaN
# freq             NaN               NaN
# mean    6.601620e+10     -3.816000e+08
# std     1.291369e+10      1.255511e+10
# min     5.077900e+10     -1.915400e+10
# 25%     5.736500e+10     -3.068000e+09
# 50%     6.484900e+10     -2.140000e+08
# 75%     7.381200e+10      5.562000e+09
# max     8.327600e+10      1.496600e+10
#
#         accumulatedOtherComprehensiveIncomeLoss  totalStockholdersEquity  \
# count                              5.000000e+00             5.000000e+00
# unique                                      NaN                      NaN
# top                                         NaN                      NaN
# freq                                        NaN                      NaN
# mean                              -5.995200e+09             5.963940e+10
# std                                5.623057e+09             5.880524e+09
# min                               -1.145200e+10             5.067200e+10
# 25%                               -1.110900e+10             5.695000e+10
# 50%                               -7.172000e+09             6.214600e+10
# 75%                               -4.060000e+08             6.309000e+10
# max                                1.630000e+08             6.533900e+10
#
#          totalEquity  totalLiabilitiesAndStockholdersEquity  \
# count   5.000000e+00                           5.000000e+00
# unique           NaN                                    NaN
# top              NaN                                    NaN
# freq             NaN                                    NaN
# mean    5.963940e+10                           3.490416e+11
# std     5.880524e+09                           1.514026e+10
# min     5.067200e+10                           3.238880e+11
# 25%     5.695000e+10                           3.510020e+11
# 50%     6.214600e+10                           3.525830e+11
# 75%     6.309000e+10                           3.527550e+11
# max     6.533900e+10                           3.649800e+11
#
#         totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# count                     5.000000e+00      5.000000e+00  5.000000e+00
# unique                             NaN               NaN           NaN
# top                                NaN               NaN           NaN
# freq                               NaN               NaN           NaN
# mean                      3.490416e+11      1.427388e+11  1.242854e+11
# std                       1.514026e+10      1.288755e+10  1.027621e+10
# min                       3.238880e+11      1.267070e+11  1.110880e+11
# 25%                       3.510020e+11      1.321340e+11  1.190590e+11
# 50%                       3.525830e+11      1.454630e+11  1.222780e+11
# 75%                       3.527550e+11      1.538140e+11  1.324800e+11
# max                       3.649800e+11      1.555760e+11  1.365220e+11
#
#              netDebt
# count   5.000000e+00
# unique           NaN
# top              NaN
# freq             NaN
# mean    9.298340e+10
# std     1.179901e+10
# min     8.112300e+10
# 25%     8.426200e+10
# 50%     8.911600e+10
# 75%     1.015820e+11
# max     1.088340e+11
#
# [11 rows x 37 columns]
#
# --- Balance Sheet.head() ---
#           acceptedDate calendarYear period  cashAndCashEquivalents  \
# 0  2024-11-01 06:01:36         2024     FY             29943000000
# 1  2023-11-02 18:08:27         2023     FY             29965000000
# 2  2022-10-27 18:01:14         2022     FY             23646000000
# 3  2021-10-28 18:04:28         2021     FY             34940000000
# 4  2020-10-29 18:06:25         2020     FY             38016000000
#
#    shortTermInvestments  cashAndShortTermInvestments  netReceivables  \
# 0           35228000000                  65171000000     66243000000
# 1           31590000000                  61555000000     60985000000
# 2           24658000000                  48304000000     60932000000
# 3           27699000000                  62639000000     51506000000
# 4           52927000000                  90943000000     37445000000
#
#     inventory  otherCurrentAssets  totalCurrentAssets  ...  commonStock  \
# 0  7286000000         14287000000        152987000000  ...  83276000000
# 1  6331000000         14695000000        143566000000  ...  73812000000
# 2  4946000000         21223000000        135405000000  ...  64849000000
# 3  6580000000         14111000000        134836000000  ...  57365000000
# 4  4061000000         11264000000        143713000000  ...  50779000000
#
#    retainedEarnings  accumulatedOtherComprehensiveIncomeLoss  \
# 0      -19154000000                              -7172000000
# 1        -214000000                             -11452000000
# 2       -3068000000                             -11109000000
# 3        5562000000                                163000000
# 4       14966000000                               -406000000
#
#    totalStockholdersEquity  totalEquity  \
# 0              56950000000  56950000000
# 1              62146000000  62146000000
# 2              50672000000  50672000000
# 3              63090000000  63090000000
# 4              65339000000  65339000000
#
#    totalLiabilitiesAndStockholdersEquity  totalLiabilitiesAndTotalEquity  \
# 0                           364980000000                    364980000000
# 1                           352583000000                    352583000000
# 2                           352755000000                    352755000000
# 3                           351002000000                    351002000000
# 4                           323888000000                    323888000000
#
#    totalInvestments     totalDebt       netDebt
# 0      126707000000  119059000000   89116000000
# 1      132134000000  111088000000   81123000000
# 2      145463000000  132480000000  108834000000
# 3      155576000000  136522000000  101582000000
# 4      153814000000  122278000000   84262000000
#
# [5 rows x 37 columns]

# %%
#cashflow statement
cashflow_statement= get_statement(company_ticker, 'cash-flow-statement', api_key, frequency = 'annual', df=True)
drop_zero_columns(cashflow_statement)
df_summary(cashflow_statement, name= 'cash flow statement')
# Out:
# effectOfForexChangesOnCash only has zero values
# --- cash flow statement.info() ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   acceptedDate                              5 non-null      object
#  1   calendarYear                              5 non-null      object
#  2   period                                    5 non-null      object
#  3   netIncome                                 5 non-null      int64
#  4   depreciationAndAmortization               5 non-null      int64
#  5   deferredIncomeTax                         5 non-null      int64
#  6   stockBasedCompensation                    5 non-null      int64
#  7   changeInWorkingCapital                    5 non-null      int64
#  8   accountsReceivables                       5 non-null      int64
#  9   inventory                                 5 non-null      int64
#  10  accountsPayables                          5 non-null      int64
#  11  otherWorkingCapital                       5 non-null      int64
#  12  otherNonCashItems                         5 non-null      int64
#  13  netCashProvidedByOperatingActivities      5 non-null      int64
#  14  investmentsInPropertyPlantAndEquipment    5 non-null      int64
#  15  acquisitionsNet                           5 non-null      int64
#  16  purchasesOfInvestments                    5 non-null      int64
#  17  salesMaturitiesOfInvestments              5 non-null      int64
#  18  otherInvestingActivites                   5 non-null      int64
#  19  netCashUsedForInvestingActivites          5 non-null      int64
#  20  debtRepayment                             5 non-null      int64
#  21  commonStockIssued                         5 non-null      int64
#  22  commonStockRepurchased                    5 non-null      int64
#  23  dividendsPaid                             5 non-null      int64
#  24  otherFinancingActivites                   5 non-null      int64
#  25  netCashUsedProvidedByFinancingActivities  5 non-null      int64
#  26  netChangeInCash                           5 non-null      int64
#  27  cashAtEndOfPeriod                         5 non-null      int64
#  28  cashAtBeginningOfPeriod                   5 non-null      int64
#  29  operatingCashFlow                         5 non-null      int64
#  30  capitalExpenditure                        5 non-null      int64
#  31  freeCashFlow                              5 non-null      int64
# dtypes: int64(29), object(3)
# memory usage: 1.4+ KB
# None
#
# --- cash flow statement.describe() ---
#                acceptedDate calendarYear period     netIncome  \
# count                     5            5      5  5.000000e+00
# unique                    5            5      1           NaN
# top     2024-11-01 06:01:36         2024     FY           NaN
# freq                      1            1      5           NaN
# mean                    NaN          NaN    NaN  8.852500e+10
# std                     NaN          NaN    NaN  1.755031e+10
# min                     NaN          NaN    NaN  5.741100e+10
# 25%                     NaN          NaN    NaN  9.373600e+10
# 50%                     NaN          NaN    NaN  9.468000e+10
# 75%                     NaN          NaN    NaN  9.699500e+10
# max                     NaN          NaN    NaN  9.980300e+10
#
#         depreciationAndAmortization  deferredIncomeTax  \
# count                  5.000000e+00       5.000000e+00
# unique                          NaN                NaN
# top                             NaN                NaN
# freq                            NaN                NaN
# mean                   1.128160e+10      -8.188000e+08
# std                    2.034092e+08       2.252008e+09
# min                    1.105600e+10      -4.774000e+09
# 25%                    1.110400e+10      -2.150000e+08
# 50%                    1.128400e+10       0.000000e+00
# 75%                    1.144500e+10       0.000000e+00
# max                    1.151900e+10       8.950000e+08
#
#         stockBasedCompensation  changeInWorkingCapital  accountsReceivables  \
# count             5.000000e+00            5.000000e+00         5.000000e+00
# unique                     NaN                     NaN                  NaN
# top                        NaN                     NaN                  NaN
# freq                       NaN                     NaN                  NaN
# mean              9.258800e+09           -1.894000e+08        -4.092400e+09
# std               2.010091e+09            5.346527e+09         8.641662e+09
# min               6.829000e+09           -6.577000e+09        -1.402800e+10
# 25%               7.906000e+09           -4.911000e+09        -9.343000e+09
# 50%               9.038000e+09            1.200000e+09        -5.144000e+09
# 75%               1.083300e+10            3.651000e+09        -4.170000e+08
# max               1.168800e+10            5.690000e+09         8.470000e+09
#
#            inventory  ...  commonStockRepurchased  dividendsPaid  \
# count   5.000000e+00  ...            5.000000e+00   5.000000e+00
# unique           NaN  ...                     NaN            NaN
# top              NaN  ...                     NaN            NaN
# freq             NaN  ...                     NaN            NaN
# mean   -7.898000e+08  ...           -8.404600e+10  -1.472960e+10
# std     1.564582e+09  ...            9.083985e+09   4.592742e+08
# min    -2.642000e+09  ...           -9.494900e+10  -1.523400e+10
# 25%    -1.618000e+09  ...           -8.940200e+10  -1.502500e+10
# 50%    -1.046000e+09  ...           -8.597100e+10  -1.484100e+10
# 75%    -1.270000e+08  ...           -7.755000e+10  -1.446700e+10
# max     1.484000e+09  ...           -7.235800e+10  -1.408100e+10
#
#         otherFinancingActivites  netCashUsedProvidedByFinancingActivities  \
# count              5.000000e+00                              5.000000e+00
# unique                      NaN                                       NaN
# top                         NaN                                       NaN
# freq                        NaN                                       NaN
# mean              -4.336000e+09                             -1.042786e+11
# std                1.640718e+09                              1.411739e+10
# min               -6.012000e+09                             -1.219830e+11
# 25%               -5.802000e+09                             -1.107490e+11
# 50%               -4.558000e+09                             -1.084880e+11
# 75%               -2.880000e+09                             -9.335300e+10
# max               -2.428000e+09                             -8.682000e+10
#
#         netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# count      5.000000e+00       5.000000e+00             5.000000e+00
# unique              NaN                NaN                      NaN
# top                 NaN                NaN                      NaN
# freq                NaN                NaN                      NaN
# mean      -4.056200e+09       3.227500e+10             3.633120e+10
# std        6.987120e+09       5.720061e+09             9.556947e+09
# min       -1.095200e+10       2.497700e+10             2.497700e+10
# 25%       -1.043500e+10       2.994300e+10             3.073700e+10
# 50%       -3.860000e+09       3.073700e+10             3.592900e+10
# 75%       -7.940000e+08       3.592900e+10             3.978900e+10
# max        5.760000e+09       3.978900e+10             5.022400e+10
#
#         operatingCashFlow  capitalExpenditure  freeCashFlow
# count        5.000000e+00        5.000000e+00  5.000000e+00
# unique                NaN                 NaN           NaN
# top                   NaN                 NaN           NaN
# freq                  NaN                 NaN           NaN
# mean         1.071320e+11       -9.901600e+09  9.723040e+10
# std          1.635927e+10        1.588793e+09  1.524310e+10
# min          8.067400e+10       -1.108500e+10  7.336500e+10
# 25%          1.040380e+11       -1.095900e+10  9.295300e+10
# 50%          1.105430e+11       -1.070800e+10  9.958400e+10
# 75%          1.182540e+11       -9.447000e+09  1.088070e+11
# max          1.221510e+11       -7.309000e+09  1.114430e+11
#
# [11 rows x 32 columns]
#
# --- cash flow statement.head() ---
#           acceptedDate calendarYear period    netIncome  \
# 0  2024-11-01 06:01:36         2024     FY  93736000000
# 1  2023-11-02 18:08:27         2023     FY  96995000000
# 2  2022-10-27 18:01:14         2022     FY  99803000000
# 3  2021-10-28 18:04:28         2021     FY  94680000000
# 4  2020-10-29 18:06:25         2020     FY  57411000000
#
#    depreciationAndAmortization  deferredIncomeTax  stockBasedCompensation  \
# 0                  11445000000                  0             11688000000
# 1                  11519000000                  0             10833000000
# 2                  11104000000          895000000              9038000000
# 3                  11284000000        -4774000000              7906000000
# 4                  11056000000         -215000000              6829000000
#
#    changeInWorkingCapital  accountsReceivables   inventory  ...  \
# 0              3651000000          -5144000000 -1046000000  ...
# 1             -6577000000           -417000000 -1618000000  ...
# 2              1200000000          -9343000000  1484000000  ...
# 3             -4911000000         -14028000000 -2642000000  ...
# 4              5690000000           8470000000  -127000000  ...
#
#    commonStockRepurchased  dividendsPaid  otherFinancingActivites  \
# 0            -94949000000   -15234000000              -5802000000
# 1            -77550000000   -15025000000              -6012000000
# 2            -89402000000   -14841000000              -2428000000
# 3            -85971000000   -14467000000              -4558000000
# 4            -72358000000   -14081000000              -2880000000
#
#    netCashUsedProvidedByFinancingActivities  netChangeInCash  \
# 0                             -121983000000       -794000000
# 1                             -108488000000       5760000000
# 2                             -110749000000     -10952000000
# 3                              -93353000000      -3860000000
# 4                              -86820000000     -10435000000
#
#    cashAtEndOfPeriod  cashAtBeginningOfPeriod  operatingCashFlow  \
# 0        29943000000              30737000000       118254000000
# 1        30737000000              24977000000       110543000000
# 2        24977000000              35929000000       122151000000
# 3        35929000000              39789000000       104038000000
# 4        39789000000              50224000000        80674000000
#
#    capitalExpenditure  freeCashFlow
# 0         -9447000000  108807000000
# 1        -10959000000   99584000000
# 2        -10708000000  111443000000
# 3        -11085000000   92953000000
# 4         -7309000000   73365000000
#
# [5 rows x 32 columns]

# %%
# financial ratios
financial_ratios= get_statement(company_ticker, 'ratios', api_key, frequency= 'annual', df= True)
drop_zero_columns(financial_ratios)
df_summary(financial_ratios, name= 'financial ratios')
# Out:
# --- financial ratios.info() ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   quickRatio                          5 non-null      float64
#  1   cashRatio                           5 non-null      float64
#  2   daysOfSalesOutstanding              5 non-null      float64
#  3   daysOfInventoryOutstanding          5 non-null      float64
#  4   operatingCycle                      5 non-null      float64
#  5   daysOfPayablesOutstanding           5 non-null      float64
#  6   cashConversionCycle                 5 non-null      float64
#  7   grossProfitMargin                   5 non-null      float64
#  8   operatingProfitMargin               5 non-null      float64
#  9   pretaxProfitMargin                  5 non-null      float64
#  10  netProfitMargin                     5 non-null      float64
#  11  effectiveTaxRate                    5 non-null      float64
#  12  returnOnAssets                      5 non-null      float64
#  13  returnOnEquity                      5 non-null      float64
#  14  returnOnCapitalEmployed             5 non-null      float64
#  15  netIncomePerEBT                     5 non-null      float64
#  16  ebtPerEbit                          5 non-null      float64
#  17  ebitPerRevenue                      5 non-null      float64
#  18  debtRatio                           5 non-null      float64
#  19  debtEquityRatio                     5 non-null      float64
#  20  longTermDebtToCapitalization        5 non-null      float64
#  21  totalDebtToCapitalization           5 non-null      float64
#  22  interestCoverage                    5 non-null      float64
#  23  cashFlowToDebtRatio                 5 non-null      float64
#  24  companyEquityMultiplier             5 non-null      float64
#  25  receivablesTurnover                 5 non-null      float64
#  26  payablesTurnover                    5 non-null      float64
#  27  inventoryTurnover                   5 non-null      float64
#  28  fixedAssetTurnover                  5 non-null      float64
#  29  assetTurnover                       5 non-null      float64
#  30  operatingCashFlowPerShare           5 non-null      float64
#  31  freeCashFlowPerShare                5 non-null      float64
#  32  cashPerShare                        5 non-null      float64
#  33  payoutRatio                         5 non-null      float64
#  34  operatingCashFlowSalesRatio         5 non-null      float64
#  35  freeCashFlowOperatingCashFlowRatio  5 non-null      float64
#  36  cashFlowCoverageRatios              5 non-null      float64
#  37  shortTermCoverageRatios             5 non-null      float64
#  38  capitalExpenditureCoverageRatio     5 non-null      float64
#  39  dividendPaidAndCapexCoverageRatio   5 non-null      float64
#  40  dividendPayoutRatio                 5 non-null      float64
#  41  priceBookValueRatio                 5 non-null      float64
#  42  priceToBookRatio                    5 non-null      float64
#  43  priceToSalesRatio                   5 non-null      float64
#  44  priceEarningsRatio                  5 non-null      float64
#  45  priceToFreeCashFlowsRatio           5 non-null      float64
#  46  priceToOperatingCashFlowsRatio      5 non-null      float64
#  47  priceCashFlowRatio                  5 non-null      float64
#  48  priceEarningsToGrowthRatio          5 non-null      float64
#  49  priceSalesRatio                     5 non-null      float64
#  50  dividendYield                       5 non-null      float64
# dtypes: float64(51)
# memory usage: 2.1 KB
# None
#
# --- financial ratios.describe() ---
#        quickRatio  cashRatio  daysOfSalesOutstanding  \
# count    5.000000   5.000000                5.000000
# mean     0.992974   0.233738               55.497383
# std      0.201626   0.085733                4.926003
# min      0.826007   0.153563               49.787534
# 25%      0.847235   0.169753               51.390969
# 50%      0.944442   0.206217               56.400205
# 75%      1.022115   0.278449               58.075649
# max      1.325072   0.360710               61.832560
#
#        daysOfInventoryOutstanding  operatingCycle  daysOfPayablesOutstanding  \
# count                    5.000000        5.000000                   5.000000
# mean                    10.305607       65.802991                 103.192897
# std                      1.874688        6.105136                  11.407859
# min                      8.075698       58.529418                  91.048190
# 25%                      8.741883       62.667561                  93.851071
# 50%                     10.791292       64.475903                 104.685277
# 75%                     11.276593       68.866941                 106.721468
# max                     12.642571       74.475130                 119.658477
#
#        cashConversionCycle  grossProfitMargin  operatingProfitMargin  \
# count             5.000000           5.000000               5.000000
# mean            -37.389906           0.427319               0.291100
# std               5.726043           0.029795               0.028608
# min             -45.183347           0.382332               0.241473
# 25%             -40.209374           0.417794               0.297824
# 50%             -37.854527           0.433096               0.298214
# 75%             -32.518772           0.441311               0.302887
# max             -31.183510           0.462063               0.315102
#
#        pretaxProfitMargin  ...  priceBookValueRatio  priceToBookRatio  \
# count            5.000000  ...             5.000000          5.000000
# mean             0.291500  ...            44.319741         44.319741
# std              0.027370  ...            11.683621         11.683621
# min              0.244398  ...            29.818270         29.818270
# 25%              0.296740  ...            38.892865         38.892865
# 50%              0.298529  ...            43.374791         43.374791
# 75%              0.302040  ...            48.140340         48.140340
# max              0.315790  ...            61.372438         61.372438
#
#        priceToSalesRatio  priceEarningsRatio  priceToFreeCashFlowsRatio  \
# count           5.000000            5.000000                   5.000000
# mean            7.192399           29.874420                  26.806751
# std             1.040438            5.499272                   3.631164
# min             6.186138           24.441824                  21.888924
# 25%             6.707591           25.916254                  26.397759
# 50%             7.032808           27.790812                  26.556204
# 75%             7.097229           33.935934                  27.068302
# max             8.938229           37.287278                  32.122569
#
#        priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# count                        5.000000            5.000000
# mean                        24.329332           24.329332
# std                          3.424688            3.424688
# min                         19.970097           19.970097
# 25%                         23.585141           23.585141
# 50%                         24.150233           24.150233
# 75%                         24.384808           24.384808
# max                         29.556381           29.556381
#
#        priceEarningsToGrowthRatio  priceSalesRatio  dividendYield
# count                    5.000000         5.000000       5.000000
# mean                    26.279426         7.192399       0.005828
# std                     83.497300         1.040438       0.001031
# min                    -45.937927         6.186138       0.004359
# 25%                      0.363486         6.707591       0.005574
# 50%                      2.887190         7.032808       0.005896
# 75%                      3.170889         7.097229       0.006084
# max                    170.913493         8.938229       0.007227
#
# [8 rows x 51 columns]
#
# --- financial ratios.head() ---
#    quickRatio  cashRatio  daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# 0    0.826007   0.169753               61.832560                   12.642571
# 1    0.944442   0.206217               58.075649                   10.791292
# 2    0.847235   0.153563               56.400205                    8.075698
# 3    1.022115   0.278449               51.390969                   11.276593
# 4    1.325072   0.360710               49.787534                    8.741883
#
#    operatingCycle  daysOfPayablesOutstanding  cashConversionCycle  \
# 0       74.475130                 119.658477           -45.183347
# 1       68.866941                 106.721468           -37.854527
# 2       64.475903                 104.685277           -40.209374
# 3       62.667561                  93.851071           -31.183510
# 4       58.529418                  91.048190           -32.518772
#
#    grossProfitMargin  operatingProfitMargin  pretaxProfitMargin  ...  \
# 0           0.462063               0.315102            0.315790  ...
# 1           0.441311               0.298214            0.296740  ...
# 2           0.433096               0.302887            0.302040  ...
# 3           0.417794               0.297824            0.298529  ...
# 4           0.382332               0.241473            0.244398  ...
#
#    priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# 0            61.372438         61.372438           8.938229
# 1            43.374791         43.374791           7.032808
# 2            48.140340         48.140340           6.186138
# 3            38.892865         38.892865           6.707591
# 4            29.818270         29.818270           7.097229
#
#    priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0           37.287278                  32.122569
# 1           27.790812                  27.068302
# 2           24.441824                  21.888924
# 3           25.916254                  26.397759
# 4           33.935934                  26.556204
#
#    priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                       29.556381           29.556381
# 1                       24.384808           24.384808
# 2                       19.970097           19.970097
# 3                       23.585141           23.585141
# 4                       24.150233           24.150233
#
#    priceEarningsToGrowthRatio  priceSalesRatio  dividendYield
# 0                  -45.937927         8.938229       0.004359
# 1                  170.913493         7.032808       0.005574
# 2                    2.887190         6.186138       0.006084
# 3                    0.363486         6.707591       0.005896
# 4                    3.170889         7.097229       0.007227
#
# [5 rows x 51 columns]

# %%
financial_ratios.columns
# Out:
# Index(['quickRatio', 'cashRatio', 'daysOfSalesOutstanding',
#        'daysOfInventoryOutstanding', 'operatingCycle',
#        'daysOfPayablesOutstanding', 'cashConversionCycle', 'grossProfitMargin',
#        'operatingProfitMargin', 'pretaxProfitMargin', 'netProfitMargin',
#        'effectiveTaxRate', 'returnOnAssets', 'returnOnEquity',
#        'returnOnCapitalEmployed', 'netIncomePerEBT', 'ebtPerEbit',
#        'ebitPerRevenue', 'debtRatio', 'debtEquityRatio',
#        'longTermDebtToCapitalization', 'totalDebtToCapitalization',
#        'interestCoverage', 'cashFlowToDebtRatio', 'companyEquityMultiplier',
#        'receivablesTurnover', 'payablesTurnover', 'inventoryTurnover',
#        'fixedAssetTurnover', 'assetTurnover', 'operatingCashFlowPerShare',
#        'freeCashFlowPerShare', 'cashPerShare', 'payoutRatio',
#        'operatingCashFlowSalesRatio', 'freeCashFlowOperatingCashFlowRatio',
#        'cashFlowCoverageRatios', 'shortTermCoverageRatios',
#        'capitalExpenditureCoverageRatio', 'dividendPaidAndCapexCoverageRatio',
#        'dividendPayoutRatio', 'priceBookValueRatio', 'priceToBookRatio',
#        'priceToSalesRatio', 'priceEarningsRatio', 'priceToFreeCashFlowsRatio',
#        'priceToOperatingCashFlowsRatio', 'priceCashFlowRatio',
#        'priceEarningsToGrowthRatio', 'priceSalesRatio', 'dividendYield'],
#       dtype='object')
