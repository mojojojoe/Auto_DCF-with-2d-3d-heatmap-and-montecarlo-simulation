# %%
import pandas as pd
df_D = pd.read_excel(r'copy_path')
df_D
# Out:
#          Row Labels  Average of Adj. Default Spread  \
# 0            Africa                        0.063367
# 1            Angola                        0.064372
# 2             Benin                        0.044583
# 3          Botswana                        0.011873
# 4      Burkina Faso                        0.074266
# ..              ...                             ...
# 162          Sweden                        0.000000
# 163     Switzerland                        0.000000
# 164          Turkey                        0.044583
# 165  United Kingdom                        0.005937
# 166     Grand Total                        0.038431
#
#      Average of Country Risk Premium  Average of Equity Risk Premium  \
# 0                           0.074777                        0.118077
# 1                           0.075963                        0.119263
# 2                           0.052611                        0.095911
# ...
